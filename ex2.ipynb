# %% [markdown]
# <a href="https://colab.research.google.com/github/Sherbl-Ab/CloudCourse/blob/main/ex2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""ex2.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/19A7GcjdkpHuOg8Zgm4OjjRRUzLlTnAUO
"""

import json
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

# Load student data from JSON file (replace 'students.json' with your file)
def load_student_data():
    try:
        with open('students.json', 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        print("Error: 'students.json' not found.")
        return []  # Initialize as empty list if file not found

# Create widgets
student_data = load_student_data()  # Load the student data initially

# Create the "Select Student" label and dropdown widget
student_selector_label = widgets.Label(value="Select Student:")
student_selector = widgets.Dropdown(
    options=[(student['name'], i) for i, student in enumerate(student_data)],
    description='',
    disabled=False,
    value=0,  # Set default selection to the first student
    layout=widgets.Layout(width='200px')  # Set the width for the dropdown
)

# Use HBox to put label and dropdown side by side for "Select Student"
student_selector_box = widgets.HBox([student_selector_label, student_selector], layout=widgets.Layout(margin='10px 0px'))

# Create the "Favorite Program:" label and text box
fav_program_label = widgets.Label(value="Favorite Program:")
fav_program_textbox = widgets.Text(
    description='',
    layout=widgets.Layout(width='190px')  # Set the width for the text box
)

# Create the "Link" label and clickable link field
link_textbox = widgets.HTML(description='Link:', value="", layout=widgets.Layout(width='300px'))

# Use HBox to put label and text box for "Favorite Program:" side by side
fav_program_box = widgets.HBox([fav_program_label, fav_program_textbox], layout=widgets.Layout(margin='10px 0px'))

# Use HBox to put label and text box for "Link:" side by side
link_box = widgets.HBox([link_textbox], layout=widgets.Layout(margin='10px 0px'))

# Text fields for student details
name_textbox = widgets.Text(description='Name:', disabled=True, layout=widgets.Layout(width='300px'))
lname_textbox = widgets.Text(description='Last Name:', disabled=True, layout=widgets.Layout(width='300px'))
email_textbox = widgets.Text(description='Email:', disabled=True, layout=widgets.Layout(width='300px'))
class_textbox = widgets.Text(description='Class:', disabled=True, layout=widgets.Layout(width='300px'))

update_button = widgets.Button(description='Update', layout=widgets.Layout(width='300px'))

output = widgets.Output()

# Function to update the displayed student details
def update_student_details(selected_index):
    with output:
        clear_output(wait=True)  # Clear the previous output
        if 0 <= selected_index < len(student_data):
            student = student_data[selected_index]
            name_textbox.value = student['name']
            lname_textbox.value = student['lname']
            email_textbox.value = student['email']
            class_textbox.value = ", ".join(student['class'])

            # Update the link with a clickable HTML element
            link_textbox.value = f'<a href="{student["link"]}" target="_blank">Click to visit link</a>'

            # Set the favorite program text box to the current favorite program if available
            fav_program_textbox.value = student.get('favorite_program', '')

        else:
            # Handle invalid index (if needed)
            print("Invalid Student Index")

# Function to update student data in JSON file
def update_student_data(button):
    with output:
        clear_output(wait=True)
        selected_index = student_selector.value
        if 0 <= selected_index < len(student_data):
            # Update the favorite program with the value from the text box
            student_data[selected_index]['favorite_program'] = fav_program_textbox.value  # Update the favorite program

            try:
                # Write the updated data to the JSON file
                with open('students.json', 'w') as f:
                    json.dump(student_data, f, indent=4)
                print("Student data updated successfully!")
            except Exception as e:
                print(f"Error updating student data: {e}")
        else:
            print("Please Select a Valid Student")

# Attach event handlers
student_selector.observe(lambda change: update_student_details(change.new), names='value')
update_button.on_click(update_student_data)

# Initialize with first student's details when the program runs
update_student_details(0)  # Manually pass the first student's index

# Display the rest of the widgets
display(student_selector_box,name_textbox, lname_textbox, email_textbox, class_textbox,link_box,fav_program_box, update_button, output)
# Out:
# Error: 'students.json' not found.
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_selection.py in findvalue(array, value, compare)
#     136     try:
# --> 137         return next(x for x in array if compare(x, value))
#     138     except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_selection.py in _validate_value(self, proposal)
#     240         try:
# --> 241             return findvalue(self._options_values, value, self.equals) if value is not None else None
#     242         except ValueError:
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_selection.py in findvalue(array, value, compare)
#     138     except StopIteration:
# --> 139         raise ValueError('%r not in array'%value)
#     140
#
# ValueError: 0 not in array
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-1-8690fa18c8d2> in <cell line: 0>()
#      26 # Create the "Select Student" label and dropdown widget
#      27 student_selector_label = widgets.Label(value="Select Student:")
# ---> 28 student_selector = widgets.Dropdown(
#      29     options=[(student['name'], i) for i, student in enumerate(student_data)],
#      30     description='',
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_selection.py in __init__(self, *args, **kwargs)
#     188             kwargs['label'], kwargs['value'] = options[0] if nonempty else (None, None)
#     189
# --> 190         super(_Selection, self).__init__(*args, **kwargs)
#     191         self._initializing_traits_ = False
#     192
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     475         """Public constructor"""
#     476         self._model_id = kwargs.pop('model_id', None)
# --> 477         super(Widget, self).__init__(**kwargs)
#     478
#     479         Widget._call_widget_constructed(self)
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#    1355             changed = set(kwargs) & set(self._traits)
#    1356             for key in changed:
# -> 1357                 value = self._traits[key]._cross_validate(self, getattr(self, key))
#    1358                 self.set_trait(key, value)
#    1359                 changes[key]['new'] = value
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in _cross_validate(self, obj, value)
#     741         if self.name in obj._trait_validators:
#     742             proposal = Bunch({"trait": self, "value": value, "owner": obj})
# --> 743             value = obj._trait_validators[self.name](obj, proposal)
#     744         elif hasattr(obj, "_%s_validate" % self.name):
#     745             meth_name = "_%s_validate" % self.name
#
# /usr/local/lib/python3.11/dist-packages/traitlets/traitlets.py in __call__(self, *args, **kwargs)
#    1227         """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#    1228         if hasattr(self, "func"):
# -> 1229             return self.func(*args, **kwargs)
#    1230         else:
#    1231             return self._init_call(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/ipywidgets/widgets/widget_selection.py in _validate_value(self, proposal)
#     241             return findvalue(self._options_values, value, self.equals) if value is not None else None
#     242         except ValueError:
# --> 243             raise TraitError('Invalid selection: value not found')
#     244
#     245     @observe('value')
#
# TraitError: Invalid selection: value not found
